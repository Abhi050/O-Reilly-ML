# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhi050/O-Reilly-ML/blob/master/Practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn


df = pd.read_csv("E:\Extra\california-housing-prices\housing.csv")
print(df.head())
print(df.describe())
print(df.isna().count())#no missing values


c=df.corr()
df["room_per_household"]=df["total_rooms"]/df["households"]
df["bedrrom_per_households"]=df["total_bedrooms"]/df["households"]
df["population_per_households"]=df["population"]/df["households"]
df.drop("total_rooms",axis=1,inplace=True)
df.drop("total_bedrooms",axis=1,inplace=True)
df.drop("population",axis=1,inplace=True)
c_new=df.corr()


from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
 

y=df["median_income"]
df.drop("median_income",axis=1,inplace=True)


from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, Imputer
num_pipeline = Pipeline([
        ('imputer',Imputer(strategy="median")),
        ('std_scaler', StandardScaler()),
    ])
df_new = num_pipeline.fit_transform(df)
print(df.describe())


'''
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(df_new,y)
y1=lin_reg.predict(df_new)

y2=y.as_matrix()

import numpy as np
acc_lin_reg=np.mean(np.abs(y-y1))*100#accuracy
'''

'''
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly= PolynomialFeatures(degree=1, include_bias=False)
x_poly=poly.fit_transform(df_new)
lin_reg = LinearRegression()
lin_reg.fit(x_poly,y)
y1=lin_reg.predict(x_poly)

y2=y.as_matrix()

import numpy as np
acc_poly=np.mean(np.abs(y-y1))*100#accuracy
'''

'''
#Ridge
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.1, solver="cholesky", random_state=42)
ridge_reg.fit(df_new,y)
y1=ridge_reg.predict(df_new)

y2=y.as_matrix()

import numpy as np
acc_ridge=np.mean(np.abs(y-y1))*100
#accuracy=63.56 for solver=cholesky ,alpha=1
'''

'''
#Lasso
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.1)
lasso_reg.fit(df_new, y)
y1=lasso_reg.predict(df_new)

y2=y.as_matrix()

import numpy as np
acc_lasso=np.mean(np.abs(y-y1))*100
#acc=72.014, aplha=0.1
#acc=108.2,alpha=0.2,overfitting
#acc=125.45,alpha=1
'''

'''
#elasticNet
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_net.fit(df_new,y)
y1=elastic_net.predict(df_new)

y2=y.as_matrix()

import numpy as np
acc_elastic=np.mean(np.abs(y-y1))*100
#acc=71.919, alpha=0.1,ratio=0.5
#acc=72.014,ratio=0 ,ridge
#acc=63.56,ratio=1,lasso
'''


'''
#SGDRegressor
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(penalty="l1", random_state=0)
sgd_reg.fit(df_new, y.ravel())
y1=sgd_reg.predict(df_new)

y2=y.as_matrix()

import numpy as np
acc_sgd=np.mean(np.abs(y-y1))*100
#SOmething is wrong,way too high accuracy
'''
